# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import os

# Base folder where your extracted features are stored
from pathlib import Path

BASE_DIR = Path.cwd() / "extracted_features"

selected_folders = [
    # "PointMAE_pretrain_centered",
    #"PointMAE_pretrain_centered_Extruded",
    # "PointMAE_pretrain_centered_Extruded_thin",
    # "PointMAE_pretrain_Default",
    #"PointMAE_pretrain_default_Extruded",
    #"PointMAE_pretrain_default_Extruded_thin",
    #"PointMAE_pretrain_OT_2D",
    "PointMAE_pretrain_normalized",
    # "PointMAE_pretrain_normalized_Extruded",
    #"PointMAE_pretrain_normalized_Extruded_thin",
    "PointMAE_pretrain_Extruded_normalized_thin_uniform",
    #"PointMAE_pretrain_Torus",
    "PointMAE_pretrain_Airplane",
]

dfs = []

for folder in selected_folders:
    folder_path = os.path.join(BASE_DIR, folder)
    # Expect exactly one CSV inside each folder
    csvs = [f for f in os.listdir(folder_path) if f.endswith(".csv")]
    if len(csvs) == 0:
        print(f"⚠️ No CSV found in {folder_path}")
        continue
    
    csv_path = os.path.join(folder_path, csvs[0])
    df = pd.read_csv(csv_path)

    # Add a column indicating which feature set these belong to
    df["method"] = folder

    dfs.append(df)

# Combine all feature sets
ALL = pd.concat(dfs, ignore_index=True)

# Extract feature columns only
feature_cols = [c for c in ALL.columns if c.startswith("feat_")]
X = ALL[feature_cols].values
methods = ALL["method"].values

print("Loaded samples:", X.shape)
print("Methods present:", np.unique(methods))

# ---- Run t-SNE ----
tsne = TSNE(n_components=2, perplexity=40, random_state=0)
X_2d = tsne.fit_transform(X)
import matplotlib.cm as cm

plt.figure(figsize=(10, 8))
unique_methods = np.unique(methods)

# Génère une colormap avec assez de couleurs uniques
colors = cm.get_cmap("tab20", len(unique_methods))

for i, m in enumerate(unique_methods):
    idx = methods == m
    plt.scatter(
        X_2d[idx, 0],
        X_2d[idx, 1],
        s=18,
        alpha=0.7,
        label=m,
        color=colors(i) 
    )

plt.legend(loc="best", fontsize=8)
plt.title("t-SNE Comparison of PointMAE Feature Extraction Variants")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()
# Out:
# Loaded samples: (5874, 1152)
# Methods present: ['PointMAE_pretrain_Airplane'
#  'PointMAE_pretrain_Extruded_normalized_thin_uniform'
#  'PointMAE_pretrain_normalized']
# C:\Users\romai\AppData\Local\Temp\ipykernel_58604\292596156.py:66: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(unique_methods))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import os

# Base folder where your extracted features are stored
from pathlib import Path

BASE_DIR = Path.cwd() / "extracted_features"

# List only the 6 selected feature folders
selected_folders = [
    # "cls_model_35_centered",
    # "cls_model_35_centered_Extruded",
    # "cls_model_35_centered_Extruded_thin",
    "cls_model_35_Default",
    # "cls_model_35_default_Extruded",
    # "cls_model_35_default_Extruded_thin",
    # "cls_model_35_normalized",
    # "cls_model_35_normalized_Extruded",
    # "cls_model_35_normalized_Extruded_thin",
    "cls_model_35_Extruded_default_thin_uniform",
    # "cls_model_35_OT_2D",
    # "cls_model_35_Torus",
    "cls_model_35_Airplane"
]

dfs = []

for folder in selected_folders:
    folder_path = os.path.join(BASE_DIR, folder)
    # Expect exactly one CSV inside each folder
    csvs = [f for f in os.listdir(folder_path) if f.endswith(".csv")]
    if len(csvs) == 0:
        print(f"⚠️ No CSV found in {folder_path}")
        continue
    
    csv_path = os.path.join(folder_path, csvs[0])
    df = pd.read_csv(csv_path)

    # Add a column indicating which feature set these belong to
    df["method"] = folder

    dfs.append(df)

# Combine all feature sets
ALL = pd.concat(dfs, ignore_index=True)

# Extract feature columns only
feature_cols = [c for c in ALL.columns if c.startswith("feat_")]
X = ALL[feature_cols].values
methods = ALL["method"].values

print("Loaded samples:", X.shape)
print("Methods present:", np.unique(methods))

# ---- Run t-SNE ----
tsne = TSNE(n_components=2, perplexity=40, random_state=0)
X_2d = tsne.fit_transform(X)
import matplotlib.cm as cm

plt.figure(figsize=(10, 8))
unique_methods = np.unique(methods)

# Génère une colormap avec assez de couleurs uniques
colors = cm.get_cmap("tab20", len(unique_methods))

for i, m in enumerate(unique_methods):
    idx = methods == m
    plt.scatter(
        X_2d[idx, 0],
        X_2d[idx, 1],
        s=18,
        alpha=0.7,
        label=m,
        color=colors(i)
    )

plt.legend(loc="best", fontsize=8)
plt.title("t-SNE Comparison of Pointnet Feature Extraction Variants")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()
# Out:
# Loaded samples: (4874, 1024)
# Methods present: ['cls_model_35_Airplane' 'cls_model_35_Default'
#  'cls_model_35_Extruded_default_thin_uniform']
# C:\Users\romai\AppData\Local\Temp\ipykernel_58604\2594394801.py:67: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(unique_methods))
